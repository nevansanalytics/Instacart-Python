# %% [markdown]
# # 4.8 Grouping Data & Aggregating Variables
# Part 1

# %%
# Import Libraries

import pandas as pd
import numpy as np
import os

# %%
# Import orders_products_merged_refined.pkl from PKL file

path = r'C:\Users\natha\OneDrive\Desktop\Data Analytics\Jupyter\09-2023 Instacart Basket Analysis'
ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged_refined.pkl'))

# %%
# Create a subset of ords_prods_merge for only the first one million entries

df = ords_prods_merge[:1000000]

# %%
# Check the shape

df.shape
# Out:
# (1000000, 18)

# %%
# Check the column names

df.head(10)
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
# 5           1  Chocolate Sandwich Cookies        61             19     5.8
# 6           1  Chocolate Sandwich Cookies        61             19     5.8
# 7           1  Chocolate Sandwich Cookies        61             19     5.8
# 8           1  Chocolate Sandwich Cookies        61             19     5.8
# 9           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   3139998      138            28                   6                 11
# 1   1977647      138            30                   6                 17
# 2    389851      709             2                   0                 21
# 3    652770      764             1                   3                 13
# 4   1813452      764             3                   4                 17
# 5   1701441      777            16                   1                  7
# 6   1871483      825             3                   2                 14
# 7   1290456      910            12                   3                 10
# 8    369558     1052            10                   1                 20
# 9    589712     1052            15                   1                 12
#
#    days_since_prior_order  is_first_order  add_to_cart_order  reordered  \
# 0                     3.0               0                  5          0
# 1                    20.0               0                  1          1
# 2                     6.0               0                 20          0
# 3                     NaN               1                 10          0
# 4                     9.0               0                 11          1
# 5                    26.0               0                  7          0
# 6                    30.0               0                  2          0
# 7                    30.0               0                  1          0
# 8                    19.0               0                  1          0
# 9                    15.0               0                  2          1
#
#   _merge    price_range_loc    busiest_days busiest_period_of_day
# 0   both  Mid-range product  Regularly busy           Most orders
# 1   both  Mid-range product  Regularly busy           Most orders
# 2   both  Mid-range product    Busiest days         Fewest orders
# 3   both  Mid-range product    Slowest days           Most orders
# 4   both  Mid-range product    Slowest days           Most orders
# 5   both  Mid-range product    Busiest days        Average orders
# 6   both  Mid-range product  Regularly busy           Most orders
# 7   both  Mid-range product    Slowest days           Most orders
# 8   both  Mid-range product    Busiest days        Average orders
# 9   both  Mid-range product    Busiest days           Most orders

# %% [markdown]
# ## Grouping Data with Pandas

# %%
# Testing the groupby() function [Step 1 of Grouping Data]

df.groupby('product_name')

# %% [markdown]
# ### We should always use the groupby() function as part of a series of steps, namely, the following:
#
# 1. Split the data into groups based on some criteria.
# 2. Apply a function to each group separately.
# 3. Combine the results into a dataframe or alternative data structure or create a new column in the current dataframe.

# %% [markdown]
# ## Aggregating Data with agg()
# 1. Split the data into groups based on “department_id.”
# 2. Apply the agg() function to each group to obtain the mean values for the “order_number” column.
# To do this, run the following code:

# %%
# Here, the groupby() function is being assigned to the df dataframe.
# This creates the pandas object for “department_id.” Onto this resulting object, the agg() function is applied.
# The agg() function will return the mean of the given column, in this case, “order_number.”

df.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.577493
# 2                17.320781
# 3                16.084944
# 4                17.530458
# 5                14.763075
# 6                16.658449
# 7                17.031590
# 8                15.076662
# 9                15.447580
# 10               18.681852
# 11               15.447411
# 12               14.327957
# 13               16.548642
# 14               16.960241
# 15               16.121948
# 16               17.803851
# 17               15.593633
# 18               19.674252
# 19               16.899756
# 20               16.255442
# 21               25.535479

# %%
# There are some aggregations that can be conducted without use of the agg() function.
# For instance, the command above could be replaced with a command that uses the mean() function to achieve the same results:

df.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 1     15.577493
# 2     17.320781
# 3     16.084944
# 4     17.530458
# 5     14.763075
# 6     16.658449
# 7     17.031590
# 8     15.076662
# 9     15.447580
# 10    18.681852
# 11    15.447411
# 12    14.327957
# 13    16.548642
# 14    16.960241
# 15    16.121948
# 16    17.803851
# 17    15.593633
# 18    19.674252
# 19    16.899756
# 20    16.255442
# 21    25.535479
# Name: order_number, dtype: float64

# %% [markdown]
# #### *Just remember the key difference in syntax between the two methods: when using agg(), put the column you want to aggregate inside the parentheses of the agg() function as an argument. When using mean() (or any other standard aggregation function), simply index the column with square brackets, then follow it with the function you want to use after the dot.*

# %% [markdown]
# # Dot Notation VS. Square Brackets

# %% [markdown]
# ### Using dot notation results in the same output as the function with brackets. Theoretically, then, we could use dot notation for your commands. However, there are a few reasons why we recommend sticking to square brackets as a general rule:
#
# *Visual Appearance: Square brackets stand out, and using them consistently will help those that may look at your code down the line understand your methods. If we suddenly decided to change to dot notation for certain operations, our colleagues wouldn’t know whether you were indexing or applying a function.*
#
# *Default Role: Square brackets have no other role in Python beyond indexing. Dots, however, do (applying pandas functions, looking for certain attributes of a dataframe, etc.). When we start using dot notation for indexing, as well, Python has to work harder to understand what we are telling it to do, which can make it slower.*
#
# In general, stick to brackets when it comes to indexing!

# %% [markdown]
# # Performing Multiple Aggregations

# %%
# This code groups the DataFrame by 'department_id' and calculates the mean, minimum, and maximum values of the 'order_number' column within each group

df.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 1                15.577493   1  99
# 2                17.320781   1  96
# 3                16.084944   1  99
# 4                17.530458   1  99
# 5                14.763075   1  99
# 6                16.658449   1  99
# 7                17.031590   1  99
# 8                15.076662   1  98
# 9                15.447580   1  99
# 10               18.681852   1  99
# 11               15.447411   1  99
# 12               14.327957   1  99
# 13               16.548642   1  99
# 14               16.960241   1  99
# 15               16.121948   1  99
# 16               17.803851   1  99
# 17               15.593633   1  99
# 18               19.674252   1  99
# 19               16.899756   1  99
# 20               16.255442   1  99
# 21               25.535479   1  98

# %% [markdown]
# # Aggregating Data with transform()

# %% [markdown]
# ### To create your flag, you’ll need some criteria. You can use the following:
#
# A. If the maximum orders the user has made is over 40, then the customer will be labeled a “Loyal customer.”
#
# B. If the maximum orders the user has made is over 10 but less than or equal to 40, then the customer will be labeled a “Regular customer.”
#
# C. If the maximum orders the user has made is less than or equal to 10, then the customer will be labeled a “New customer.”

# %% [markdown]
# ### Now, let’s map this task onto the three-step process introduced earlier:
#
# 1. Split the data into groups based on the “user_id” column.
# 2. Apply the transform() function on the “order_number” column to generate the maximum orders for each user.
# 3. Create a new column, “max_order,” into which you’ll place the results of your aggregation.

# %%
# In this case, all three steps can be included in a single line of code:

ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %% [markdown]
# ### This code adds a new column called 'max_order' to the DataFrame `ords_prods_merge`. The values in this column are calculated based on a group operation.
#
# Specifically, it does the following:
#
# 1. **`ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)`**:
#    - It groups the DataFrame `ords_prods_merge` by the 'user_id' column.
#    - Within each group, it selects the 'order_number' column.
#    - It then applies the `np.max` function, which finds the maximum value within each group.
#    - This operation returns a Series with the maximum order number for each user.
#
# 2. **`ords_prods_merge['max_order'] = ...`**:
#    - It assigns the Series obtained in the previous step to a new column named 'max_order' in the DataFrame `ords_prods_merge`.
#
# In summary, this code calculates the maximum order number for each user and stores it in a new column called 'max_order' in the DataFrame `ords_prods_merge`.

# %%
# Check the columns

ords_prods_merge.head(15)
# Out:
#     product_id                product_name  aisle_id  department_id  prices  \
# 0            1  Chocolate Sandwich Cookies        61             19     5.8
# 1            1  Chocolate Sandwich Cookies        61             19     5.8
# 2            1  Chocolate Sandwich Cookies        61             19     5.8
# 3            1  Chocolate Sandwich Cookies        61             19     5.8
# 4            1  Chocolate Sandwich Cookies        61             19     5.8
# 5            1  Chocolate Sandwich Cookies        61             19     5.8
# 6            1  Chocolate Sandwich Cookies        61             19     5.8
# 7            1  Chocolate Sandwich Cookies        61             19     5.8
# 8            1  Chocolate Sandwich Cookies        61             19     5.8
# 9            1  Chocolate Sandwich Cookies        61             19     5.8
# 10           1  Chocolate Sandwich Cookies        61             19     5.8
# 11           1  Chocolate Sandwich Cookies        61             19     5.8
# 12           1  Chocolate Sandwich Cookies        61             19     5.8
# 13           1  Chocolate Sandwich Cookies        61             19     5.8
# 14           1  Chocolate Sandwich Cookies        61             19     5.8
#
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0    3139998      138            28                   6                 11
# 1    1977647      138            30                   6                 17
# 2     389851      709             2                   0                 21
# 3     652770      764             1                   3                 13
# 4    1813452      764             3                   4                 17
# 5    1701441      777            16                   1                  7
# 6    1871483      825             3                   2                 14
# 7    1290456      910            12                   3                 10
# 8     369558     1052            10                   1                 20
# 9     589712     1052            15                   1                 12
# 10   1798115     1379             1                   5                 11
# 11    497193     1480            36                   3                 13
# 12   1727826     1480            38                   4                 13
# 13   2694698     1480            39                   2                 12
# 14   3171753     1494             6                   3                 10
#
#     days_since_prior_order  is_first_order  add_to_cart_order  reordered  \
# 0                      3.0               0                  5          0
# 1                     20.0               0                  1          1
# 2                      6.0               0                 20          0
# 3                      NaN               1                 10          0
# 4                      9.0               0                 11          1
# 5                     26.0               0                  7          0
# 6                     30.0               0                  2          0
# 7                     30.0               0                  1          0
# 8                     19.0               0                  1          0
# 9                     15.0               0                  2          1
# 10                     NaN               1                  1          0
# 11                     7.0               0                  1          0
# 12                     7.0               0                  3          1
# 13                    12.0               0                  4          1
# 14                     2.0               0                  8          0
#
#    _merge    price_range_loc    busiest_days busiest_period_of_day  max_order
# 0    both  Mid-range product  Regularly busy           Most orders         32
# 1    both  Mid-range product  Regularly busy           Most orders         32
# 2    both  Mid-range product    Busiest days         Fewest orders          5
# 3    both  Mid-range product    Slowest days           Most orders          3
# 4    both  Mid-range product    Slowest days           Most orders          3
# 5    both  Mid-range product    Busiest days        Average orders         26
# 6    both  Mid-range product  Regularly busy           Most orders          9
# 7    both  Mid-range product    Slowest days           Most orders         12
# 8    both  Mid-range product    Busiest days        Average orders         20
# 9    both  Mid-range product    Busiest days           Most orders         20
# 10   both  Mid-range product  Regularly busy           Most orders         10
# 11   both  Mid-range product    Slowest days           Most orders         43
# 12   both  Mid-range product    Slowest days           Most orders         43
# 13   both  Mid-range product  Regularly busy           Most orders         43
# 14   both  Mid-range product    Slowest days           Most orders         13

# %% [markdown]
# ### *The max_order column represents the highest order number for each user in the DataFrame ords_prods_merge. In other words, it indicates the most recent order number for each individual user. This information can be useful for various analyses, such as identifying loyal or frequent customers, tracking customer behavior over time, and understanding the ordering patterns of different users.*

# %%
# Compare 'order_number' against 'max_order' for 'user_id' of 1

ords_prods_merge[ords_prods_merge['user_id'] == 1].head(100)
# Out:
#           product_id                             product_name  aisle_id  \
# 92368            196                                     Soda        77
# 92369            196                                     Soda        77
# 92370            196                                     Soda        77
# 92371            196                                     Soda        77
# 92372            196                                     Soda        77
# 92373            196                                     Soda        77
# 92374            196                                     Soda        77
# 92375            196                                     Soda        77
# 92376            196                                     Soda        77
# 92377            196                                     Soda        77
# 5971715        10258                               Pistachios       117
# 5971716        10258                               Pistachios       117
# 5971717        10258                               Pistachios       117
# 5971718        10258                               Pistachios       117
# 5971719        10258                               Pistachios       117
# 5971720        10258                               Pistachios       117
# 5971721        10258                               Pistachios       117
# 5971722        10258                               Pistachios       117
# 5971723        10258                               Pistachios       117
# 6002731        10326                      Organic Fuji Apples        24
# 7157228        12427                      Original Beef Jerky        23
# 7157229        12427                      Original Beef Jerky        23
# 7157230        12427                      Original Beef Jerky        23
# 7157231        12427                      Original Beef Jerky        23
# 7157232        12427                      Original Beef Jerky        23
# 7157233        12427                      Original Beef Jerky        23
# 7157234        12427                      Original Beef Jerky        23
# 7157235        12427                      Original Beef Jerky        23
# 7157236        12427                      Original Beef Jerky        23
# 7157237        12427                      Original Beef Jerky        23
# 7453170        13032                    Cinnamon Toast Crunch       121
# 7453171        13032                    Cinnamon Toast Crunch       121
# 7453172        13032                    Cinnamon Toast Crunch       121
# 7518961        13176                   Bag of Organic Bananas        24
# 7518962        13176                   Bag of Organic Bananas        24
# 8435031        14084  Organic Unsweetened Vanilla Almond Milk        91
# 10076906       17122                        Honeycrisp Apples        24
# 16105125       25133                    Organic String Cheese        21
# 16105126       25133                    Organic String Cheese        21
# 16105127       25133                    Organic String Cheese        21
# 16105128       25133                    Organic String Cheese        21
# 16105129       25133                    Organic String Cheese        21
# 16105130       25133                    Organic String Cheese        21
# 16105131       25133                    Organic String Cheese        21
# 16105132       25133                    Organic String Cheese        21
# 16642084       26088               Aged White Cheddar Popcorn        23
# 16642085       26088               Aged White Cheddar Popcorn        23
# 17009387       26405         XL Pick-A-Size Paper Towel Rolls        54
# 17009388       26405         XL Pick-A-Size Paper Towel Rolls        54
# 19830897       30450                     Creamy Almond Butter        88
# 23227386       35951          Organic Unsweetened Almond Milk        91
# 24921181       38928                 0% Greek Strained Yogurt       120
# 25452452       39657                   Milk Chocolate Almonds        45
# 26745407       41787                           Bartlett Pears        24
# 29711949       46149                        Zero Calorie Cola        77
# 29711950       46149                        Zero Calorie Cola        77
# 29711951       46149                        Zero Calorie Cola        77
# 32033308       49235                      Organic Half & Half        53
# 32033309       49235                      Organic Half & Half        53
#
#           department_id  prices  order_id  user_id  order_number  \
# 92368                 7     9.0   2539329        1             1
# 92369                 7     9.0   2398795        1             2
# 92370                 7     9.0    473747        1             3
# 92371                 7     9.0   2254736        1             4
# 92372                 7     9.0    431534        1             5
# 92373                 7     9.0   3367565        1             6
# 92374                 7     9.0    550135        1             7
# 92375                 7     9.0   3108588        1             8
# 92376                 7     9.0   2295261        1             9
# 92377                 7     9.0   2550362        1            10
# 5971715              19     3.0   2398795        1             2
# 5971716              19     3.0    473747        1             3
# 5971717              19     3.0   2254736        1             4
# 5971718              19     3.0    431534        1             5
# 5971719              19     3.0   3367565        1             6
# 5971720              19     3.0    550135        1             7
# 5971721              19     3.0   3108588        1             8
# 5971722              19     3.0   2295261        1             9
# 5971723              19     3.0   2550362        1            10
# 6002731               4     2.7    431534        1             5
# 7157228              19     4.4   2539329        1             1
# 7157229              19     4.4   2398795        1             2
# 7157230              19     4.4    473747        1             3
# 7157231              19     4.4   2254736        1             4
# 7157232              19     4.4    431534        1             5
# 7157233              19     4.4   3367565        1             6
# 7157234              19     4.4    550135        1             7
# 7157235              19     4.4   3108588        1             8
# 7157236              19     4.4   2295261        1             9
# 7157237              19     4.4   2550362        1            10
# 7453170              14     4.0   2398795        1             2
# 7453171              14     4.0    550135        1             7
# 7453172              14     4.0   2550362        1            10
# 7518961               4    10.3   2398795        1             2
# 7518962               4    10.3    431534        1             5
# 8435031              16    12.5   2539329        1             1
# 10076906              4    14.0    431534        1             5
# 16105125             16     8.6    473747        1             3
# 16105126             16     8.6   2254736        1             4
# 16105127             16     8.6    431534        1             5
# 16105128             16     8.6   3367565        1             6
# 16105129             16     8.6    550135        1             7
# 16105130             16     8.6   3108588        1             8
# 16105131             16     8.6   2295261        1             9
# 16105132             16     8.6   2550362        1            10
# 16642084             19     4.7   2539329        1             1
# 16642085             19     4.7   2398795        1             2
# 17009387             17     1.0   2539329        1             1
# 17009388             17     1.0   2254736        1             4
# 19830897             13     3.2    473747        1             3
# 23227386             16     1.3   2550362        1            10
# 24921181             16    12.6   2550362        1            10
# 25452452             19     6.8   2550362        1            10
# 26745407              4     5.0    431534        1             5
# 29711949              7    13.4   3108588        1             8
# 29711950              7    13.4   2295261        1             9
# 29711951              7    13.4   2550362        1            10
# 32033308             16     1.8   3108588        1             8
# 32033309             16     1.8   2295261        1             9
#
#           orders_day_of_week  order_hour_of_day  days_since_prior_order  \
# 92368                      2                  8                     NaN
# 92369                      3                  7                    15.0
# 92370                      3                 12                    21.0
# 92371                      4                  7                    29.0
# 92372                      4                 15                    28.0
# 92373                      2                  7                    19.0
# 92374                      1                  9                    20.0
# 92375                      1                 14                    14.0
# 92376                      1                 16                     0.0
# 92377                      4                  8                    30.0
# 5971715                    3                  7                    15.0
# 5971716                    3                 12                    21.0
# 5971717                    4                  7                    29.0
# 5971718                    4                 15                    28.0
# 5971719                    2                  7                    19.0
# 5971720                    1                  9                    20.0
# 5971721                    1                 14                    14.0
# 5971722                    1                 16                     0.0
# 5971723                    4                  8                    30.0
# 6002731                    4                 15                    28.0
# 7157228                    2                  8                     NaN
# 7157229                    3                  7                    15.0
# 7157230                    3                 12                    21.0
# 7157231                    4                  7                    29.0
# 7157232                    4                 15                    28.0
# 7157233                    2                  7                    19.0
# 7157234                    1                  9                    20.0
# 7157235                    1                 14                    14.0
# 7157236                    1                 16                     0.0
# 7157237                    4                  8                    30.0
# 7453170                    3                  7                    15.0
# 7453171                    1                  9                    20.0
# 7453172                    4                  8                    30.0
# 7518961                    3                  7                    15.0
# 7518962                    4                 15                    28.0
# 8435031                    2                  8                     NaN
# 10076906                   4                 15                    28.0
# 16105125                   3                 12                    21.0
# 16105126                   4                  7                    29.0
# 16105127                   4                 15                    28.0
# 16105128                   2                  7                    19.0
# 16105129                   1                  9                    20.0
# 16105130                   1                 14                    14.0
# 16105131                   1                 16                     0.0
# 16105132                   4                  8                    30.0
# 16642084                   2                  8                     NaN
# 16642085                   3                  7                    15.0
# 17009387                   2                  8                     NaN
# 17009388                   4                  7                    29.0
# 19830897                   3                 12                    21.0
# 23227386                   4                  8                    30.0
# 24921181                   4                  8                    30.0
# 25452452                   4                  8                    30.0
# 26745407                   4                 15                    28.0
# 29711949                   1                 14                    14.0
# 29711950                   1                 16                     0.0
# 29711951                   4                  8                    30.0
# 32033308                   1                 14                    14.0
# 32033309                   1                 16                     0.0
#
#           is_first_order  add_to_cart_order  reordered _merge  \
# 92368                  1                  1          0   both
# 92369                  0                  1          1   both
# 92370                  0                  1          1   both
# 92371                  0                  1          1   both
# 92372                  0                  1          1   both
# 92373                  0                  1          1   both
# 92374                  0                  1          1   both
# 92375                  0                  2          1   both
# 92376                  0                  4          1   both
# 92377                  0                  1          1   both
# 5971715                0                  2          0   both
# 5971716                0                  3          1   both
# 5971717                0                  3          1   both
# 5971718                0                  3          1   both
# 5971719                0                  3          1   both
# 5971720                0                  2          1   both
# 5971721                0                  3          1   both
# 5971722                0                  5          1   both
# 5971723                0                  6          1   both
# 6002731                0                  5          0   both
# 7157228                1                  3          0   both
# 7157229                0                  3          1   both
# 7157230                0                  2          1   both
# 7157231                0                  2          1   both
# 7157232                0                  2          1   both
# 7157233                0                  2          1   both
# 7157234                0                  3          1   both
# 7157235                0                  1          1   both
# 7157236                0                  6          1   both
# 7157237                0                  9          1   both
# 7453170                0                  6          0   both
# 7453171                0                  5          1   both
# 7453172                0                  8          1   both
# 7518961                0                  4          0   both
# 7518962                0                  8          1   both
# 8435031                1                  2          0   both
# 10076906               0                  6          0   both
# 16105125               0                  4          0   both
# 16105126               0                  4          1   both
# 16105127               0                  4          1   both
# 16105128               0                  4          1   both
# 16105129               0                  4          1   both
# 16105130               0                  4          1   both
# 16105131               0                  3          1   both
# 16105132               0                  5          1   both
# 16642084               1                  4          0   both
# 16642085               0                  5          1   both
# 17009387               1                  5          0   both
# 17009388               0                  5          1   both
# 19830897               0                  5          0   both
# 23227386               0                  7          0   both
# 24921181               0                  4          0   both
# 25452452               0                  3          0   both
# 26745407               0                  7          0   both
# 29711949               0                  5          0   both
# 29711950               0                  2          1   both
# 29711951               0                  2          1   both
# 32033308               0                  6          0   both
# 32033309               0                  1          1   both
#
#             price_range_loc    busiest_days busiest_period_of_day  max_order
# 92368     Mid-range product  Regularly busy        Average orders         10
# 92369     Mid-range product    Slowest days        Average orders         10
# 92370     Mid-range product    Slowest days           Most orders         10
# 92371     Mid-range product    Slowest days        Average orders         10
# 92372     Mid-range product    Slowest days           Most orders         10
# 92373     Mid-range product  Regularly busy        Average orders         10
# 92374     Mid-range product    Busiest days           Most orders         10
# 92375     Mid-range product    Busiest days           Most orders         10
# 92376     Mid-range product    Busiest days           Most orders         10
# 92377     Mid-range product    Slowest days        Average orders         10
# 5971715   Low-range product    Slowest days        Average orders         10
# 5971716   Low-range product    Slowest days           Most orders         10
# 5971717   Low-range product    Slowest days        Average orders         10
# 5971718   Low-range product    Slowest days           Most orders         10
# 5971719   Low-range product  Regularly busy        Average orders         10
# 5971720   Low-range product    Busiest days           Most orders         10
# 5971721   Low-range product    Busiest days           Most orders         10
# 5971722   Low-range product    Busiest days           Most orders         10
# 5971723   Low-range product    Slowest days        Average orders         10
# 6002731   Low-range product    Slowest days           Most orders         10
# 7157228   Low-range product  Regularly busy        Average orders         10
# 7157229   Low-range product    Slowest days        Average orders         10
# 7157230   Low-range product    Slowest days           Most orders         10
# 7157231   Low-range product    Slowest days        Average orders         10
# 7157232   Low-range product    Slowest days           Most orders         10
# 7157233   Low-range product  Regularly busy        Average orders         10
# 7157234   Low-range product    Busiest days           Most orders         10
# 7157235   Low-range product    Busiest days           Most orders         10
# 7157236   Low-range product    Busiest days           Most orders         10
# 7157237   Low-range product    Slowest days        Average orders         10
# 7453170   Low-range product    Slowest days        Average orders         10
# 7453171   Low-range product    Busiest days           Most orders         10
# 7453172   Low-range product    Slowest days        Average orders         10
# 7518961   Mid-range product    Slowest days        Average orders         10
# 7518962   Mid-range product    Slowest days           Most orders         10
# 8435031   Mid-range product  Regularly busy        Average orders         10
# 10076906  Mid-range product    Slowest days           Most orders         10
# 16105125  Mid-range product    Slowest days           Most orders         10
# 16105126  Mid-range product    Slowest days        Average orders         10
# 16105127  Mid-range product    Slowest days           Most orders         10
# 16105128  Mid-range product  Regularly busy        Average orders         10
# 16105129  Mid-range product    Busiest days           Most orders         10
# 16105130  Mid-range product    Busiest days           Most orders         10
# 16105131  Mid-range product    Busiest days           Most orders         10
# 16105132  Mid-range product    Slowest days        Average orders         10
# 16642084  Low-range product  Regularly busy        Average orders         10
# 16642085  Low-range product    Slowest days        Average orders         10
# 17009387  Low-range product  Regularly busy        Average orders         10
# 17009388  Low-range product    Slowest days        Average orders         10
# 19830897  Low-range product    Slowest days           Most orders         10
# 23227386  Low-range product    Slowest days        Average orders         10
# 24921181  Mid-range product    Slowest days        Average orders         10
# 25452452  Mid-range product    Slowest days        Average orders         10
# 26745407  Low-range product    Slowest days           Most orders         10
# 29711949  Mid-range product    Busiest days           Most orders         10
# 29711950  Mid-range product    Busiest days           Most orders         10
# 29711951  Mid-range product    Slowest days        Average orders         10
# 32033308  Low-range product    Busiest days           Most orders         10
# 32033309  Low-range product    Busiest days           Most orders         10

# %%
pd.options.display.max_rows = None

# This command tells pandas not to assign any options regarding the maximum number of rows to display.
# After executing this line of code, try your head() function again.
# We should now see all 100 rows, which will allow you to check whether your aggregation procedure was conducted successfully.
# Keep in mind that having an output this large in your Jupyter notebook will inflate its size significantly!
# We can simply delete that output later by navigating to the Cell menu → Current Outputs → Clear.

# %% [markdown]
# # Deriving Columns with loc()

# %%
# With your new column ready to go,
# All that’s left is to create a flag that assigns a “loyalty” label to a user ID based on its corresponding max order value.
# We should be familiar with the process already from the previous Exercise.
# Based on the criteria listed above, our code should look like:

ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
# Check the value counts of our new 'loyalty_flag' column

ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# loyalty_flag
# Regular customer    15876363
# Loyal customer      10284010
# New customer         6243788
# Name: count, dtype: int64

# %%
# Cross checking user_id, loyalty_flag and max_order for logic

ords_prods_merge[['user_id', 'loyalty_flag', 'max_order']].head(60)
# Out:
#     user_id      loyalty_flag  max_order
# 0       138  Regular customer         32
# 1       138  Regular customer         32
# 2       709      New customer          5
# 3       764      New customer          3
# 4       764      New customer          3
# 5       777  Regular customer         26
# 6       825      New customer          9
# 7       910  Regular customer         12
# 8      1052  Regular customer         20
# 9      1052  Regular customer         20
# 10     1379      New customer         10
# 11     1480    Loyal customer         43
# 12     1480    Loyal customer         43
# 13     1480    Loyal customer         43
# 14     1494  Regular customer         13
# 15     1494  Regular customer         13
# 16     1494  Regular customer         13
# 17     1540  Regular customer         28
# 18     1540  Regular customer         28
# 19     1540  Regular customer         28
# 20     1540  Regular customer         28
# 21     1540  Regular customer         28
# 22     1540  Regular customer         28
# 23     1540  Regular customer         28
# 24     1540  Regular customer         28
# 25     1540  Regular customer         28
# 26     1540  Regular customer         28
# 27     1540  Regular customer         28
# 28     1540  Regular customer         28
# 29     1540  Regular customer         28
# 30     1540  Regular customer         28
# 31     1540  Regular customer         28
# 32     1540  Regular customer         28
# 33     1540  Regular customer         28
# 34     1598      New customer          4
# 35     1598      New customer          4
# 36     1598      New customer          4
# 37     1647      New customer         10
# 38     1647      New customer         10
# 39     1647      New customer         10
# 40     1647      New customer         10
# 41     1647      New customer         10
# 42     2833      New customer         10
# 43     2850  Regular customer         23
# 44     2857  Regular customer         25
# 45     3010  Regular customer         13
# 46     3029      New customer          5
# 47     3395      New customer          6
# 48     3904      New customer          3
# 49     4006    Loyal customer         42
# 50     4006    Loyal customer         42
# 51     4006    Loyal customer         42
# 52     4006    Loyal customer         42
# 53     4006    Loyal customer         42
# 54     4122  Regular customer         40
# 55     4141      New customer          9
# 56     4343      New customer          4
# 57     4553      New customer          4
# 58     4845  Regular customer         14
# 59     6866      New customer          6

# %%
df.head(10)
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
# 5           1  Chocolate Sandwich Cookies        61             19     5.8
# 6           1  Chocolate Sandwich Cookies        61             19     5.8
# 7           1  Chocolate Sandwich Cookies        61             19     5.8
# 8           1  Chocolate Sandwich Cookies        61             19     5.8
# 9           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   3139998      138            28                   6                 11
# 1   1977647      138            30                   6                 17
# 2    389851      709             2                   0                 21
# 3    652770      764             1                   3                 13
# 4   1813452      764             3                   4                 17
# 5   1701441      777            16                   1                  7
# 6   1871483      825             3                   2                 14
# 7   1290456      910            12                   3                 10
# 8    369558     1052            10                   1                 20
# 9    589712     1052            15                   1                 12
#
#    days_since_prior_order  is_first_order  add_to_cart_order  reordered  \
# 0                     3.0               0                  5          0
# 1                    20.0               0                  1          1
# 2                     6.0               0                 20          0
# 3                     NaN               1                 10          0
# 4                     9.0               0                 11          1
# 5                    26.0               0                  7          0
# 6                    30.0               0                  2          0
# 7                    30.0               0                  1          0
# 8                    19.0               0                  1          0
# 9                    15.0               0                  2          1
#
#   _merge    price_range_loc    busiest_days busiest_period_of_day
# 0   both  Mid-range product  Regularly busy           Most orders
# 1   both  Mid-range product  Regularly busy           Most orders
# 2   both  Mid-range product    Busiest days         Fewest orders
# 3   both  Mid-range product    Slowest days           Most orders
# 4   both  Mid-range product    Slowest days           Most orders
# 5   both  Mid-range product    Busiest days        Average orders
# 6   both  Mid-range product  Regularly busy           Most orders
# 7   both  Mid-range product    Slowest days           Most orders
# 8   both  Mid-range product    Busiest days        Average orders
# 9   both  Mid-range product    Busiest days           Most orders
